# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-030d740a-571b-4c76-b1b3-d61cb7f6bd44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-030d740a-571b-4c76-b1b3-d61cb7f6bd44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_aerated_drinks.csv to urls_aerated_drinks.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-5169eb2f-b885-42a1-a8af-9b7addee3069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5169eb2f-b885-42a1-a8af-9b7addee3069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_apple.csv to urls_apple.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-64288e70-17a4-45f6-8b74-9b7868bb4a7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64288e70-17a4-45f6-8b74-9b7868bb4a7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_applepie.csv to urls_applepie.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-02b7d5d8-bd24-47c3-a174-2ff7af33eb03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02b7d5d8-bd24-47c3-a174-2ff7af33eb03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_chapati.csv to urls_chapati.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-9fc07574-b2e0-4ffc-b789-2f583de0bd95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fc07574-b2e0-4ffc-b789-2f583de0bd95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_dal makhani.csv to urls_dal makhani.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-224c75b0-88c7-4838-a3c5-b14065ae78db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-224c75b0-88c7-4838-a3c5-b14065ae78db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_green_salad.csv to urls_green_salad.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-3cf01940-79a1-4000-980c-ff549c860a0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cf01940-79a1-4000-980c-ff549c860a0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_Grilled_sandwich.csv to urls_Grilled_sandwich.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-67aa2f86-7b3a-41fa-88e6-274161abf0c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67aa2f86-7b3a-41fa-88e6-274161abf0c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_jalebi.csv to urls_jalebi.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-52ed2e91-2a2f-4214-bab5-ad145e4b9712" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52ed2e91-2a2f-4214-bab5-ad145e4b9712">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_noodles.csv to urls_noodles.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-2887e99a-e18c-45e5-8d25-d6d2183527cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2887e99a-e18c-45e5-8d25-d6d2183527cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_omelete.csv to urls_omelete.csv

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-be69e0fb-9087-4cb9-96f6-50eb21e1ecc1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be69e0fb-9087-4cb9-96f6-50eb21e1ecc1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls_Samosa.csv to urls_Samosa.csv

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
img_counter=[]
img_counter.append(10)

# %%
folder = 'Samosa'
url_file = 'urls_Samosa.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Samosa'
url_file = 'urls_Samosa.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=550)

# %%
folder = 'jalebi'
url_file = 'urls_jalebi.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
url_file = 'urls_jalebi.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=500)

# %%
folder = 'Dal makhani'
url_file = 'urls_dal makhani.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
url_file = 'urls_dal makhani.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=450)

# %%
folder = 'Chapati'
url_file = 'urls_chapati.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Chapati'
url_file = 'urls_chapati.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=400)

# %%
folder = 'Grilled sandwich'
url_file = 'urls_Grilled_sandwich.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Grilled sandwich'
url_file = 'urls_Grilled_sandwich.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=350)

# %%
folder = 'Aerated drinks'
url_file = 'urls_aerated_drinks.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
url_file = 'urls_aerated_drinks.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=300)

# %%
folder = 'Noodles'
url_file = 'urls_noodles.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
url_file = 'urls_noodles.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=250)

# %%
folder = 'Omelete'
url_file = 'urls_omelete.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Omelete'
url_file = 'urls_omelete.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=200)

# %%
folder = 'Green salad'
url_file = 'urls_green_salad.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Green salad'
url_file = 'urls_green_salad.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=150)

# %%
folder = 'Apples'
url_file = 'urls_apple.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Apples'
url_file = 'urls_apple.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=100)

# %%
folder = 'Apple pie'
url_file = 'urls_applepie.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'Apple pie'
url_file = 'urls_applepie.csv'
path = Path('test_data')
dest = path
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=50)

# %%
classes = ['Apple pie','Apple', 'Areated drinks','Green salad','Omelete','Noodles','Aerated drinks','Grilled sandwich','Chapati','Dal makhani','jalebi','Samosa']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# Apple pie
# Apple
# Areated drinks
# Green salad
# Omelete
# Noodles
# Aerated drinks
# Grilled sandwich
# Chapati
# Dal makhani
# jalebi
# Samosa

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder("my_data", train="train_data", valid_pct=0.2,ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Aerated drinks',
#  'Apple pie',
#  'Apples',
#  'Chapati',
#  'Dal makhani',
#  'Green salad',
#  'Grilled sandwich',
#  'Noodles',
#  'Omelete',
#  'Samosa',
#  'jalebi']

# %%
data.show_batch(rows=3, figsize=(8,8))

# %%
bs=64

# %%
path=""
tfms = get_transforms(do_flip=True)
data = ImageDataBunch.from_folder( Path("my_data"), valid_pct=0.2, bs=64, size=224, ds_tfms=get_transforms())

# %%
learn = cnn_learner(data, models.resnet50, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.102059</td>
#       <td>0.614063</td>
#       <td>0.831325</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.750982</td>
#       <td>0.452156</td>
#       <td>0.861909</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.516983</td>
#       <td>0.398395</td>
#       <td>0.883225</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.369306</td>
#       <td>0.371799</td>
#       <td>0.885079</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-0')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.705072</td>
#       <td>0.971540</td>
#       <td>0.799815</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.485956</td>
#       <td>0.377648</td>
#       <td>0.893420</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot()

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.makedirs("/content/drive/My Drive/dl_projects/food_recognition",exist_ok=True)

# %%
my_dir="/content/drive/My Drive/dl_projects/food_recognition"

# %%
learn.save(my_dir+"/Stage-1")

# %%
learn.load("/content/drive/My Drive/dl_projects/food_recognition/Stage-1")
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (4317 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Grilled sandwich,Grilled sandwich,Grilled sandwich,Grilled sandwich,Grilled sandwich
# Path: my_data;
#
# Valid: LabelList (1079 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# Aerated drinks,Chapati,Omelete,Aerated drinks,Chapati
# Path: my_data;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
# ...

# %%
learn.export(my_dir+"/export.pkl")

# %%
predictor = load_learner(my_dir)

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.254947</td>
#       <td>0.338349</td>
#       <td>0.903614</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.224412</td>
#       <td>0.344493</td>
#       <td>0.902688</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
def my_predictor(im):
  test_img =open_image(im)
  pred_class,pred_idx,outputs=predictor.predict(test_img)
  return pred_class

# %%
all_test_images=os.listdir("test_data/")

# %%
idx=2
print(my_predictor("test_data/"+all_test_images[idx]))
img = open_image("test_data/"+all_test_images[idx])
img.show()
# Out:
# Noodles
